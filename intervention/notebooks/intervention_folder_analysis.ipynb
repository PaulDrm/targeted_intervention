# %%
# import re 
# import os 
# from tqdm.notebook import tqdm
# import pandas as pd
# path = "./intervention_results/test_1702_no"
# files = []
# ## get all files in a directory
# for file in tqdm(os.listdir(path)):
#     if "train" in file: 
        
#         files.append(os.path.join(path, file))
# files = sorted(files)
# for file in files: 
#     print(file)
#     try:
#         df = pd.read_json(file)
#         print(df.predict.value_counts())
#     except:
#         pass

# %%
# import re 
# import os 
# from tqdm.notebook import tqdm
# import pandas as pd
# path = "./intervention_results/test_1702_no"
# files = []
# ## get all files in a directory
# for file in tqdm(os.listdir(path)):
#     if "valid" in file: 
        
#         files.append(os.path.join(path, file))
# files = sorted(files, reverse=True)
# for file in files: 
#     print(file)
#     try:
#         df = pd.read_json(file)
#         print(df.predict.value_counts())
#     except:
#         pass

# %%
import re 
import os 
from tqdm.notebook import tqdm
import pandas as pd
path = "./intervention_results/test_1702_no"
files = []
## get all files in a directory
for file in tqdm(os.listdir(path)):
    if "train" in file: 
        
        files.append(os.path.join(path, file))
files = sorted(files)
for file in files: 
    print(file)
    try:
        df = pd.read_json(file)
        print(df.predict.value_counts())
    except:
        pass

# %%
import re 
import os 
from tqdm.notebook import tqdm
import pandas as pd
path = "../app/"
files = []
## get all files in a directory
for file in tqdm(os.listdir(path)):
    if "results__test" in file: 
        
        files.append(os.path.join(path, file))
files = sorted(files)
for file in files: 
    print(file)
    try:
        df = pd.read_json(file)
        print(df.predict.value_counts())
    except:
        pass
# Out:
#   0%|          | 0/119 [00:00<?, ?it/s]
# ../app/results__test_openchat_intervention_15_16.json
# predict
# no           26
# yes          15
# undefined     6
# Name: count, dtype: int64
# ../app/results__test_openchat_intervention_15_2.json
# predict
# no           32
# yes           9
# undefined     6
# Name: count, dtype: int64
# ../app/results__test_openchat_intervention_15_4.json
# predict
# no           32
# yes           8
# undefined     7
# Name: count, dtype: int64
# ../app/results__test_openchat_intervention_15_8.json
# predict
# no           26
# yes          17
# undefined     4
# Name: count, dtype: int64
# ../app/results__test_openchat_intervention_20_16.json
# predict
# no           26
# yes          18
# undefined     3
# Name: count, dtype: int64
# ../app/results__test_openchat_intervention_20_2.json
# predict
# no           33
# undefined     8
# yes           6
# Name: count, dtype: int64
# ../app/results__test_openchat_intervention_20_4.json
# predict
# ...
